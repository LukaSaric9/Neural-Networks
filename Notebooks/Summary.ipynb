# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
tfidf_df = pd.read_csv("../Results/tfidf_results.csv")
lstm_df = pd.read_csv("../Results/lstm_results.csv")
bert_df = pd.read_csv("../Results/bert_results.csv")
